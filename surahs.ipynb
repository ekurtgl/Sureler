# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sureler = pd.read_excel('surahs.xlsx')
print(sureler.to_string())
# Out:
#      Sıra         Sûre  Ayet Sayısı  Nuzül Sırası
# 0       1      Fâtiha             7             5
# 1       2      Bakara           286            87
# 2       3  Âl-i İmrân           200            89
# 3       4        Nisâ           176            92
# 4       5       Mâide           120           112
# 5       6       En'âm           165            55
# 6       7       A'râf           206            39
# 7       8       Enfâl            75            88
# 8       9       Tevbe           129           113
# 9      10       Yunus           109            51
# 10     11         Hûd           123            52
# 11     12       Yusuf           111            53
# 12     13        Ra'd            43            96
# 13     14     İbrahim            52            72
# 14     15        Hicr            99            54
# 15     16        Nahl           128            70
# 16     17        İsrâ           111            50
# 17     18        Kehf           110            69
# ...

# %%
sure_isimleri = sureler['Sûre']
# Out:
# 0          Fâtiha
# 1          Bakara
# 2      Âl-i İmrân
# 3            Nisâ
# 4           Mâide
#           ...
# 109          Nasr
# 110        Tebbet
# 111         İhlâs
# 112         Felâk
# 113           Nâs
# Name: Sûre, Length: 114, dtype: object

# %%
fig = plt.figure(figsize=(20, 8), dpi=100)
ax = fig.gca()
plt.grid('both')
p1, = plt.plot(sureler['Ayet Sayısı'], label='Ayet Sayısı')
p2, = plt.plot(sureler['Nuzül Sırası'], label='Nuzül Sırası')
ax.set_xlabel('Sure Adi')
ax.set_xticks(sureler['Sıra'] - 1)
plt.xticks(rotation=90)
ax.set_xticklabels(sureler['Sûre'])
ax.invert_xaxis()
plt.legend()
plt.show()
